# %%
import os

DIR = r'c://downloads'

# %% [markdown]
# # Using a custom module

# %%
import sys

sys.path

# %%
sys.path.append(DIR)
print(sys.path)

# %%
from genome_reader import read_seq

# %%
# From: ftp://hgdownload.cse.ucsc.edu/goldenPath/hg19/chromosomes/chr11.fa.gz
print(read_seq(os.path.join(DIR, 'chr11.fa'), 100123, 100955))

# %%
# Modules are yet another Python object.
import genome_reader
module1 = genome_reader
print(module1.read_seq)

# %%
# On rare occasions, it can be useful to load a module by its name using __import__ 
module_name = 'genome_reader'
module2 = __import__(module_name)
print(module2.read_seq)
print(module1 is module2)

# %% [markdown]
# # exec & eval

# %%
exec('a = 55')
print(a)

# %%
b = eval('a ** 2')
print(b)

# %%
with open(os.path.join(DIR, 'genome_reader.py'), 'r') as f:
    exec(f.read())

print(ChromosomeReader)

# %% [markdown]
# Unlike importing, this executes everything in the target file in the same namespace, as if we copied it here and ran it.
#
# It's sometimes more convenient than importing if we don't want to create a full module, but just running some code, or during the developement of a module (it overcomes most of the problems of reloading modules).

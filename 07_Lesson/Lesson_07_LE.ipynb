# %% [markdown]
# # Lesson 07 Lab Exercises

# %%
import os
import numpy as np
import pandas as pd
from IPython.display import display
from openpyxl import load_workbook
DIR = '/Users/fernandojuarez/Documents/GitHub/Quantitative_Biological_Research_Python_course/'

# %% [markdown]
# # Exercise 1

# %% [markdown]
# Load viperdb.csv with Pandas.
#
# Call simple Pandas functions to achieve the following tasks:

# %%
df = pd.read_csv(os.path.join(DIR, '07_Lesson/Files/viperdb.csv'))

# %%
# display(df)
# display(df.describe())

# %% [markdown]
# ## Part A
# Find the virus record with the largest outer capsid radius.

# %%
# print('The virus with the largest outer capsid radius of %d is %s' %(df['Outer Radius'].max(), df['Title'][df['Outer Radius'].idxmax()]))
print(f"The virus with the largest outer capsid radius of {df['Outer Radius'].max()} is {df['Title'][df['Outer Radius'].idxmax()]}.")
# Out:
# The virus with the largest outer capsid radius of 929 is PBCV-1 virus capsid, quasi-atomic model.

# %% [markdown]
# ## Part B
# Calculate the correlation between inner and outer capsid radius.

# %%
print(f"The correlation between the inner and outer capsid radius is {df['Inner Radius'].corr(df['Outer Radius'])}")
print('The correlation between the inner and outer capsid radius is %0.3f' %(df['Inner Radius'].corr(df['Outer Radius'])))
# Out:
# The correlation between the inner and outer capsid radius is 0.9353034053307225
# The correlation between the inner and outer capsid radius is 0.935

# %% [markdown]
# ## Part C
# Which viruses are larger? dsDNA or ssRNA?

# %%
contains_dsDNA = df['Genome'].str.contains('dsDNA', na=False)
contains_ssRNA = df['Genome'].str.contains('ssRNA', na=False)

filter_for_dsDNA = df[contains_dsDNA]
filter_for_ssRNA = df[contains_ssRNA]

print('The average outer capsid radius for dsDNA viruses is %0.2f units' %(filter_for_dsDNA['Outer Radius'].mean()))
print('The average outer capsid radius for ssRNA viruses is %0.2f units' %(filter_for_ssRNA['Outer Radius'].mean()))
# Out:
# The average outer capsid radius for dsDNA viruses is 293.46 units
# The average outer capsid radius for ssRNA viruses is 174.35 units

# %% [markdown]
# ## Part D
# Assuming that viral capsids are roughly spherical, their surface area can be calculated by the formula 𝐴 =
# 4𝜋𝑅^2 where 𝑅 is the outer radius. Calculate this term for all virus records and add it to the DataFrame as
# a new column. How is it correlated with the Outside SASA field?

# %%
# Apply a function to a column and add it as a new column
# Find correlation between outside SASA field and new column

df['Surface Area'] = df['Outer Radius'].map(lambda x: 4*np.pi*(x**2))

print('The correlation between the estimated viral capsid Surface Area and the Outside SASA'\
      ' is %0.3f units.' %(df['Surface Area'].corr(df['Outside SASA'])))
# Out:
# The correlation between the estimated viral capsid Surface Area and the Outside SASA is 0.424 units.

# %% [markdown]
# # Exercise 2

# %% [markdown]
# ## Part A
# Download the PDF file cancer_facts.pdf and extract the table “Estimated Number of New Cases for
# Selected Cancers by State, US, 2014” into a CSV file. Use an online PDF-to-Excel tool such as:
# https://www.coolutils.com/online/PDF-to-CSV.
#
# '07_Lesson/Files/cancer_facts.xlsx'

# %% [markdown]
# ## Part B
# Which state has the highest proportion of new Leukemia cases as a fraction of all cancer types?

# %%
# df = pd.read_excel(os.path.join(DIR, '07_Lesson/Files/cancer_facts.xlsx'), skiprows=366, header=0, usecols='B:N', nrows=(425-366))
# display(df)

def parse_table(header_start, colrange, row_start, row_end):
    return pd.read_excel(os.path.join(DIR, '07_Lesson/Files/cancer_facts.xlsx'),\
                          skiprows=header_start, header=0, usecols=colrange, nrows=(row_end-row_start))

df = parse_table(366, 'B:N', 366, 425)
display(df)

# need another function for cleaning up
# Out:
#                            Unnamed: 1 Unnamed: 2  Unnamed: 3 Both Sexes  \
# 0                           All Sites        NaN         NaN  1,665,540
# 1               Oral cavity & pharynx        NaN         NaN     42,440
# 2                              Tongue        NaN         NaN     13,590
# 3                               Mouth        NaN         NaN     11,920
# 4                             Pharynx        NaN         NaN     14,410
# 5                   Other oral cavity        NaN         NaN      2,520
# 6                    Digestive system        NaN         NaN    289,610
# 7                           Esophagus        NaN         NaN     18,170
# 8                             Stomach        NaN         NaN     22,220
# 9                     Small intestine        NaN         NaN      9,160
# 10                                  †        NaN         NaN        NaN
# 11                              Colon        NaN         NaN     96,830
# 12                             Rectum        NaN         NaN     40,000
# 13      Anus, anal canal, & anorectum        NaN         NaN      7,210
# 14     Liver & intrahepatic bile duct        NaN         NaN     33,190
# 15        Gallbladder & other biliary        NaN         NaN     10,650
# 16                           Pancreas        NaN         NaN     46,420
# 17             Other digestive organs        NaN         NaN      5,760
# 18                 Respiratory system        NaN         NaN    242,550
# 19                             Larynx        NaN         NaN     12,630
# 20                    Lung & bronchus        NaN         NaN    224,210
# 21           Other respiratory organs        NaN         NaN      5,710
# 22                     Bones & joints        NaN         NaN      3,020
# 23      Soft tissue (including heart)        NaN         NaN     12,020
# 24  Skin (excluding basal & squamous)        NaN         NaN     81,220
# 25                      Melanoma-skin        NaN         NaN     76,100
# 26           Other nonepithelial skin        NaN         NaN      5,120
# 27                             Breast        NaN         NaN    235,030
# 28                     Genital system        NaN         NaN    338,450
# 29                     Uterine cervix        NaN         NaN     12,360
# 30                     Uterine corpus        NaN         NaN     52,630
# 31                              Ovary        NaN         NaN     21,980
# 32                              Vulva        NaN         NaN      4,850
# 33     Vagina & other genital, female        NaN         NaN      3,170
# 34                           Prostate        NaN         NaN    233,000
# 35                             Testis        NaN         NaN      8,820
# 36        Penis & other genital, male        NaN         NaN      1,640
# 37                     Urinary system        NaN         NaN    141,610
# 38                    Urinary bladder        NaN         NaN     74,690
# 39              Kidney & renal pelvis        NaN         NaN     63,920
# 40      Ureter & other urinary organs        NaN         NaN      3,000
# 41                        Eye & orbit        NaN         NaN      2,730
# 42       Brain & other nervous system        NaN         NaN     23,380
# 43                   Endocrine system        NaN         NaN     65,630
# 44                            Thyroid        NaN         NaN     62,980
# 45                    Other endocrine        NaN         NaN      2,650
# 46                           Lymphoma        NaN         NaN     79,990
# 47                   Hodgkin lymphoma        NaN         NaN      9,190
# 48               Non-Hodgkin lymphoma        NaN         NaN     70,800
# 49                            Myeloma        NaN         NaN     24,050
# 50                           Leukemia        NaN         NaN     52,380
# 51         Acute lymphocytic leukemia        NaN         NaN      6,020
# 52       Chronic lymphocytic leukemia        NaN         NaN     15,720
# 53             Acute myeloid leukemia        NaN         NaN     18,860
# 54           Chronic myeloid leukemia        NaN         NaN      5,980
# 55                                NaN          ‡         NaN        NaN
# 56                     Other leukemia        NaN         NaN      5,800
# 57                                NaN        NaN         NaN          ‡
# 58  Other & unspecified primary sites        NaN         NaN     31,430
#
#        Male  Unnamed: 6   Female  Unnamed: 8 Both Sexes.1   Male.1  \
# 0   855,220         NaN  810,320         NaN      585,720  310,010
# 1    30,220         NaN   12,220         NaN        8,390    5,730
# 2     9,720         NaN    3,870         NaN        2,150    1,450
# 3     7,150         NaN    4,770         NaN        2,070    1,130
# 4    11,550         NaN    2,860         NaN        2,540    1,900
# 5     1,800         NaN      720         NaN        1,630    1,250
# 6   162,730         NaN  126,880         NaN      147,260   84,970
# 7    14,660         NaN    3,510         NaN       15,450   12,450
# 8    13,730         NaN    8,490         NaN       10,990    6,720
# 9     4,880         NaN    4,280         NaN        1,210      640
# 10      NaN         NaN      NaN         NaN          NaN      NaN
# 11   48,450         NaN   48,380         NaN       50,310   26,270
# 12   23,380         NaN   16,620         NaN          NaN      NaN
# 13    2,660         NaN    4,550         NaN          950      370
# 14   24,600         NaN    8,590         NaN       23,000   15,870
# 15    4,960         NaN    5,690         NaN        3,630    1,610
# 16   23,530         NaN   22,890         NaN       39,590   20,170
# 17    1,880         NaN    3,880         NaN        2,130      870
# 18  130,000         NaN  112,550         NaN      163,660   90,280
# 19   10,000         NaN    2,630         NaN        3,610    2,870
# 20  116,000         NaN  108,210         NaN      159,260   86,930
# 21    4,000         NaN    1,710         NaN          790      480
# 22    1,680         NaN    1,340         NaN        1,460      830
# 23    6,550         NaN    5,470         NaN        4,740    2,550
# 24   46,630         NaN   34,590         NaN       12,980    8,840
# 25   43,890         NaN   32,210         NaN        9,710    6,470
# 26    2,740         NaN    2,380         NaN        3,270    2,370
# 27    2,360         NaN  232,670         NaN       40,430      430
# 28  243,460         NaN   94,990         NaN       58,970   30,180
# 29      NaN         NaN   12,360         NaN        4,020      NaN
# 30      NaN         NaN   52,630         NaN        8,590      NaN
# 31      NaN         NaN   21,980         NaN       14,270      NaN
# 32      NaN         NaN    4,850         NaN        1,030      NaN
# 33      NaN         NaN    3,170         NaN          880      NaN
# 34  233,000         NaN      NaN         NaN       29,480   29,480
# 35    8,820         NaN      NaN         NaN          380      380
# 36    1,640         NaN      NaN         NaN          320      320
# 37   97,420         NaN   44,190         NaN       30,350   20,610
# 38   56,390         NaN   18,300         NaN       15,580   11,170
# 39   39,140         NaN   24,780         NaN       13,860    8,900
# 40    1,890         NaN    1,110         NaN          910      540
# 41    1,440         NaN    1,290         NaN          310      130
# 42   12,820         NaN   10,560         NaN       14,320    8,090
# 43   16,600         NaN   49,030         NaN        2,820    1,300
# 44   15,190         NaN   47,790         NaN        1,890      830
# 45    1,410         NaN    1,240         NaN          930      470
# 46   43,340         NaN   36,650         NaN       20,170   11,140
# 47    5,070         NaN    4,120         NaN        1,180      670
# 48   38,270         NaN   32,530         NaN       18,990   10,470
# 49   13,500         NaN   10,550         NaN       11,090    6,110
# 50   30,100         NaN   22,280         NaN       24,090   14,040
# 51    3,140         NaN    2,880         NaN        1,440      810
# 52    9,100         NaN    6,620         NaN        4,600    2,800
# 53   11,530         NaN    7,330         NaN       10,460    6,010
# 54    3,130         NaN    2,850         NaN          810      550
# 55      NaN         NaN      NaN         NaN          NaN      NaN
# 56    3,200         NaN    2,600         NaN        6,780    3,870
# 57      NaN         NaN      NaN         NaN          NaN      NaN
# 58   16,370         NaN   15,060         NaN       44,680   24,780
#
#     Unnamed: 11 Female.1  Unnamed: 13
# 0           NaN  275,710          NaN
# 1           NaN    2,660          NaN
# 2           NaN      700          NaN
# 3           NaN      940          NaN
# 4           NaN      640          NaN
# 5           NaN      380          NaN
# 6           NaN   62,290          NaN
# 7           NaN    3,000          NaN
# 8           NaN    4,270          NaN
# 9           NaN      570          NaN
# 10          NaN      NaN          NaN
# 11          NaN   24,040          NaN
# 12          NaN      NaN          NaN
# 13          NaN      580          NaN
# 14          NaN    7,130          NaN
# 15          NaN    2,020          NaN
# 16          NaN   19,420          NaN
# 17          NaN    1,260          NaN
# 18          NaN   73,380          NaN
# 19          NaN      740          NaN
# 20          NaN   72,330          NaN
# 21          NaN      NaN        310.0
# 22          NaN      630          NaN
# 23          NaN    2,190          NaN
# 24          NaN    4,140          NaN
# 25          NaN    3,240          NaN
# 26          NaN      900          NaN
# 27          NaN   40,000          NaN
# 28          NaN   28,790          NaN
# 29          NaN    4,020          NaN
# 30          NaN    8,590          NaN
# 31          NaN   14,270          NaN
# 32          NaN    1,030          NaN
# 33          NaN      880          NaN
# 34          NaN      NaN          NaN
# 35          NaN      NaN          NaN
# 36          NaN      NaN          NaN
# 37          NaN    9,740          NaN
# 38          NaN    4,410          NaN
# 39          NaN    4,960          NaN
# 40          NaN      370          NaN
# 41          NaN      180          NaN
# 42          NaN    6,230          NaN
# 43          NaN    1,520          NaN
# 44          NaN    1,060          NaN
# 45          NaN      460          NaN
# 46          NaN    9,030          NaN
# 47          NaN      NaN        510.0
# 48          NaN    8,520          NaN
# 49          NaN    4,980          NaN
# 50          NaN   10,050          NaN
# 51          NaN      630          NaN
# 52          NaN    1,800          NaN
# 53          NaN    4,450          NaN
# 54          NaN      260          NaN
# 55          NaN      NaN          NaN
# 56          NaN    2,910          NaN
# 57          NaN      NaN          NaN
# 58          NaN   19,900          NaN

# %% [markdown]
# ## Part C
# What is the percentage of new cancer cases not classified as one of the provided types per state?

# %% [markdown]
# ## Part D
# Find the two states that are most similar to each other with respect to the profile of new cancer types.
#
# Compare the fraction of cancer types, not the absolute values.
